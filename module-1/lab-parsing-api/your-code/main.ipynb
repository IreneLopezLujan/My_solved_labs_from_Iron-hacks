# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %% [markdown]
# # your code here

# %%
import json
import requests
import pandas as pd
import urllib
from pandas import json_normalize

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
url= 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
url= 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=0&sort=popularity'
response = urllib.request.urlopen(url)
results = json.load(response)


flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.head()
# Out:
#              sku                                               name  \
# 0  AD111A0Q7-A11  STAN SMITH - Baskets basses - footwear white/g...
# 1  AN611BA4P-Q11                     Escarpins à plateforme - black
# 2  LE221G031-K11  ORIGINAL TRUCKER - Veste en jean - soft as but...
# 3  AN611E015-Q11                                    Derbies - black
# 4  AN651M01V-D11               Montre à aiguilles - silver-coloured
#
#                                                sizes  \
# 0  [36, 38, 40, 42, 36 2/3, 37 1/3, 38 2/3, 39 1/...
# 1                           [36, 37, 38, 39, 40, 41]
# 2                                 [XXS, XS, S, M, L]
# 3                       [36, 37, 38, 39, 40, 41, 42]
# 4                                         [One Size]
#
#                                              url_key  \
# 0  adidas-originals-stan-smith-baskets-basses-foo...
# 1  anna-field-escarpins-compenses-black-an611ba4p...
# 2  levisr-original-trucker-veste-en-jean-soft-as-...
# 3             anna-field-derbies-black-an611e015-q11
# 4  anna-field-montre-a-aiguilles-silver-coloured-...
#
#                                                media        brand_name  \
# 0  [{'path': 'spp-media-p1/566391dd3ffb3feca398e7...  adidas Originals
# 1  [{'path': 'spp-media-p1/a00b49ce7d93303c86891e...        Anna Field
# 2  [{'path': 'spp-media-p1/b06b79cb3ac83c549f3008...           Levi's®
# 3  [{'path': 'spp-media-p1/b5a88759ee2e39598040fb...        Anna Field
# 4  [{'path': 'spp-media-p1/25aa18eecaca3ecbad99de...        Anna Field
#
#    is_premium family_articles  \
# 0       False              []
# 1       False              []
# 2       False              []
# 3       False              []
# 4       False              []
#
#                                                flags product_group  \
# 0  [{'key': 'discountRate', 'value': '-25%', 'tra...          shoe
# 1  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 2  [{'key': 'discountRate', 'value': '-30%', 'tra...      clothing
# 3  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe
# 4  [{'key': 'discountRate', 'value': '-25%', 'tra...   accessoires
#
#   delivery_promises price.original price.promotional  \
# 0                []        99,95 €           74,95 €
# 1                []        34,99 €           29,69 €
# 2                []       119,95 €           83,95 €
# 3                []        39,99 €           33,99 €
# 4                []        22,99 €           17,29 €
#
#    price.has_different_prices  price.has_different_original_prices  \
# 0                       False                                False
# 1                       False                                False
# 2                       False                                False
# 3                       False                                False
# 4                       False                                False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    price.has_discount_on_selected_sizes_only amount price.base_price
# 0                                      False    NaN              NaN
# 1                                      False    NaN              NaN
# 2                                      False    NaN              NaN
# 3                                      False    NaN              NaN
# 4                                      False    NaN              NaN

# %%
response = get_zalando_page_info()
total_pages = response['pagination']['page_count']

total_pages
# Your code

frames = []


for page in range(2, total_pages+1):
    
    response = get_zalando_page_info(page*84)
    articles = pd.json_normalize(response['articles'])
    frames.append(articles)

data_set = pd.concat(frames)

data_set.set_index('sku', inplace=True)

data_set
# Out:
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=84&sort=sale
# 892
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=168&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=252&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=336&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=420&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=504&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=588&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=672&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=756&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=840&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=924&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1008&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1092&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1176&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1260&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1344&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1428&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1512&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1596&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1680&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1764&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1848&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=1932&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2016&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2100&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2184&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2268&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2352&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2436&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2520&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2604&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2688&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2772&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2856&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=2940&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3024&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3108&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3192&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3276&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3360&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3444&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3528&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3612&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3696&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3780&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3864&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=3948&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4032&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4116&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4200&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4284&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4368&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4452&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4536&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4620&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4704&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4788&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4872&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=4956&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5040&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5124&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5208&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5292&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5376&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5460&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5544&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5628&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5712&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5796&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5880&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=5964&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6048&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6132&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6216&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6300&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6384&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6468&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6552&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6636&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6720&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6804&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6888&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=6972&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7056&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7140&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7224&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7308&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7392&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7476&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7560&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7644&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7728&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7812&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7896&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=7980&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8064&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8148&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8232&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8316&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8400&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8484&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8568&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8652&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8736&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8820&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8904&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=8988&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9072&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9156&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9240&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9324&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9408&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9492&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9576&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9660&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9744&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9828&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9912&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=9996&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10080&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10164&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10248&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10332&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10416&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10500&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10584&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10668&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10752&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10836&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=10920&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11004&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11088&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11172&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11256&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11340&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11424&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11508&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11592&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11676&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11760&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11844&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=11928&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12012&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12096&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12180&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12264&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12348&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12432&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12516&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12600&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12684&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12768&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12852&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=12936&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13020&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13104&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13188&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13272&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13356&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13440&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13524&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13608&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13692&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13776&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13860&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=13944&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14028&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14112&sort=sale
# https://www.zalando.fr/api/catalog/articles/?categories=promo-femme&limit=84&offset=14196&sort=sale

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
